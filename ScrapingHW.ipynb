# %% [markdown]
# <a href="https://colab.research.google.com/github/Leenayesh/Leenayesh.github.io/blob/main/ScrapingHW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
import os

# %%
URL = "https://yougov.co.uk/ratings/food/popularity/supermarket-chains/all"

# %%
html = requests.get(URL)
soup = BeautifulSoup(html.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-gb"><head>
# <meta charset="utf-8"/>
# <title>The most popular supermarket chains in the UK | Food | YouGov Ratings</title>
# <base href="/"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="noarchive" name="robots"/>
# <link href="https://d39be2hlyrutg8.cloudfront.net/static/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://dev.visualwebsiteoptimizer.com/" rel="dns-prefetch"/>
# <link href="https://dev.visualwebsiteoptimizer.com/" rel="preconnect"/>
# <link href="https://www.google-analytics.com/" rel="dns-prefetch"/>
# <link href="https://www.google-analytics.com/" rel="preconnect"/>
# <link href="https://www.googletagmanager.com/" rel="dns-prefetch"/>
# <link href="https://www.googletagmanager.com/" rel="preconnect"/>
# <link href="https://cdn-ukwest.onetrust.com/" rel="dns-prefetch"/>
# <link href="https://cdn-ukwest.onetrust.com/" rel="preconnect"/>
# <link href="https://d18lkz4dllo6v2.cloudfront.net/" rel="dns-prefetch"/>
# <link href="https://d18lkz4dllo6v2.cloudfront.net/" rel="preconnect"/>
# <link href="https://d3hjzzsa8cr26l.cloudfront.net/" rel="dns-prefetch"/>
# <link href="https://d3hjzzsa8cr26l.cloudfront.net/" rel="preconnect"/>
# <link href="https://d39be2hlyrutg8.cloudfront.net/" rel="dns-prefetch"/>
# <link href="https://d39be2hlyrutg8.cloudfront.net/" rel="preconnect"/>
# <link as="font" crossorigin="" href="https://d39be2hlyrutg8.cloudfront.net/6d2f5632/assets/fonts/rawline/rawline-400.woff2" rel="preload" type="font/woff2"/>
# <style>html{line-height:1.15;-webkit-text-size-adjust:100%}body{margin:0}@font-face{font-family:YgRawline;src:local("YgRawline 400"),local("YgRawline-400"),url(https://d39be2hlyrutg8.cloudfront.net/6d2f5632/assets/fonts/rawline/rawline-400.woff2) format("woff2"),url(https://d39be2hlyrutg8.cloudfront.net/6d2f5632/assets/fonts/rawline/rawline-400.woff) format("woff");font-style:normal;font-weight:400;font-display:block}@font-face{font-family:YgRawline;src:local("YgRawline 500"),local("YgRawline-500"),url(https://d39be2hlyrutg8.cloudfront.net/6d2f5632/assets/fonts/rawline/rawline-500.woff2) format("woff2"),url(https://d39be2hlyrutg8.cloudfront.net/6d2f5632/assets/fonts/rawline/rawline-500.woff) format("woff");font-style:normal;font-weight:500;font-display:block}@font-face{font-family:YgRawline;src:local("YgRawline 700"),local("YgRawline-700"),url(https://d39be2hlyrutg8.cloudfront.net/6d2f5632/assets/fonts/rawline/rawline-700.woff2) format("woff2"),url(https://d39be2hlyrutg8.cloudfront.net/6d2f5632/assets/fonts/rawline/rawline-700.woff) format("woff");font-style:normal;font-weight:700;font-display:block}@font-face{font-family:YgRawline;src:local("YgRawline 800"),local("YgRawline-800"),url(https://d39be2hlyrutg8.cloudfront.net/6d2f5632/assets/fonts/rawline/rawline-800.woff2) format("woff2"),url(https://d39be2hlyrutg8.cloudfront.net/6d2f5632/assets/fonts/rawline/rawline-800.woff) format("woff");font-style:normal;font-weight:800;font-display:block}@font-face{font-family:YgRawline;src:local("YgRawline 900"),local("YgRawline-900"),url(https://d39be2hlyrutg8.cloudfront.net/6d2f5632/assets/fonts/rawline/rawline-900.woff2) format("woff2"),url(https://d39be2hlyrutg8.cloudfront.net/6d2f5632/assets/fonts/rawline/rawline-900.woff) format("woff");font-style:normal;font-weight:900;font-display:block}*,:after,:before{box-sizing:border-box}body{font-family:YgRawline,Helvetica,Arial,sans-serif;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;font-size:1rem;font-variant-ligatures:none;line-height:1.5;color:#3e3f41;position:relative;letter-spacing:.015em}yg-root{position:relative;display:flex}</style><link href="https://d39be2hlyrutg8.cloudfront.net/6d2f5632/styles.css" media="print" onload="this.media='all'" rel="stylesheet"/><noscript><link href="https://d39be2hlyrutg8.cloudfront.net/6d2f5632/styles.css" rel="stylesheet"/></noscript>
# <!-- OneTrust Cookies Consent Notice start -->
# <script src="https://cdn-ukwest.onetrust.com/consent/2435f2d2-3949-4f29-88ac-e4401b25cd83/OtAutoBlock.js" type="text/javascript"></script>
# <script charset="UTF-8" data-document-language="true" data-domain-script="2435f2d2-3949-4f29-88ac-e4401b25cd83" src="https://cdn-ukwest.onetrust.com/scripttemplates/otSDKStub.js" type="text/javascript"></script>
# <script type="text/javascript">
#             function OptanonWrapper() {}
#           </script>
# <!-- OneTrust Cookies Consent Notice end -->
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam-cell.nr-data.net","errorBeacon":"bam-cell.nr-data.net","licenseKey":"28418fab15","applicationID":"83384987","applicationTime":3.14778,"transactionName":"YVFaZEdTWkZRBhBYC1gbdl9HX1VZWR8BVTFEXRdCVEZdW1cWSxs=","queueTime":0,"ttGuid":"ba0a7399be7d16bb","agentToken":null}; (window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:true},ajax:{deny_list:["bam-cell.nr-data.net"]},distributed_tracing:{enabled:true}};(window.NREUM||(NREUM={})).loader_config={agentID:"594291322",accountID:"370703",trustKey:"370703",xpid:"VwEHVlZQGwsDV1lWDgkA",licenseKey:"28418fab15",applicationID:"83384987"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(32),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{l?l-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(33),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError";if(!c.disabled){var l=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(14),t(13),"addEventListener"in window&&t(7),c.xhrWrappable&&t(15),d=!0)}s.on("fn-start",function(t,e,n){d&&(l+=1)}),s.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})}},{}],3:[function(t,e,n){var r=t("loader");r.disabled||(r.features.ins=!0)},{}],4:[function(t,e,n){function r(){U++,L=g.hash,this[u]=y.now()}function o(){U--,g.hash!==L&&i(0,!0);var t=y.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+g,e])}function a(t,e){t.on(e,function(){this[e]=y.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,p="cb"+s,l="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,g=w.location,y=t("loader");if(w[v]&&y.xhrWrappable&&!y.disabled){var x=t(11),b=t(12),E=t(9),R=t(7),O=t(14),T=t(8),P=t(15),S=t(10),M=t("ee"),N=M.get("tracer"),C=t(23);t(17),y.features.spa=!0;var L,U=0;M.on(u,r),b.on(p,r),S.on(p,r),M.on(d,o),b.on(l,o),S.on(l,o),M.buffer([u,d,"xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+c,"clearTimeout"+s,u]),P.buffer([u,"new-xhr","send-xhr"+s]),T.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),x.buffer([u]),b.buffer(["propagate",p,l,"executor-err","resolve"+s]),N.buffer([u,"no-"+u]),S.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(T,m+s),a(T,m+"-done"),a(S,"new-jsonp"),a(S,"jsonp-end"),a(S,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,C(!0)),w[v]("load",i,C(!0)),w[v]("popstate",function(){i(0,U>1)},C(!0))}},{}],5:[function(t,e,n){function r(){var t=new PerformanceObserver(function(t,e){var n=t.getEntries();s(v,[n])});try{t.observe({entryTypes:["resource"]})}catch(e){}}function o(t){if(s(v,[window.performance.getEntriesByType(w)]),window.performance["c"+p])try{window.performance[h](m,o,!1)}catch(t){}else try{window.performance[h]("webkit"+m,o,! ...
# <script>
#           window.appConfig = {
#     "cmsApiPrefix": "",
#     "contentLanguageCode": "en-gb",
#     "disqusShortName": "yougovuk",
#     "globalCmsApiPrefix": "/apis/cms/v1",
#     "globalCmsApiRegion": "en",
#     "googleTagManagerId": "GTM-MRSS3JG",
#     "inconvoAppCode": "",
#     "inconvoAppKey": "",
#     "inconvoAppSecret": "",
#     "languageCode": "en-gb",
#     "marketo": {
#         "formId": 1006,
#         "munchkinId": "464-VHH-988"
#     },
#     "oneTrustId": "2435f2d2-3949-4f29-88ac-e4401b25cd83",
#     "publicApiPrefix": "/_pubapis/v5",
#     "publicApiRegion": "uk",
#     "recaptchaMarketoSiteKey": "6LeOlI8UAAAAACjYQXxbo6aTPzSf52D6ZpUku2Zm",
#     "siteId": 53,
#     "websiteDomain": "yougov.co.uk"
# };
#
#           // Google Tag Manager.
#           (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#           new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#           j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#           'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#           })(window,document,'script','dataLayer',window.appConfig.googleTagManagerId);
#           // End Google Tag Manager.
#         </script><style yg-transition="">main[_yg-server-content-sc83]{display:flex;flex-direction:column;min-height:calc(100vh - 100px)}.app-container[_yg-server-content-sc83]{width:100%}yg-header[_yg-server-content-sc83]{display:block;position:relative;top:0;z-index:130}yg-header[_yg-server-content-sc83]:not(.homepage){position:sticky}</style><style yg-transition=""></style><style yg-transition="">@keyframes COLOR_BAR{0%{width:0}to{width:100%}}.site-footer[_yg-server-content-sc82]{display:flex;flex-direction:column;font-size:14px;padding-top:40px;border-radius:2px;background-color:#f3f3fb}@media (max-width:599.95px),(min-width:600px) and (max-width:839.95px),(min-width:840px) and (max-width:959.95px){.site-footer[_yg-server-content-sc82]{padding-top:28px}}.site-footer[_yg-server-content-sc82] > *[_yg-server-content-sc82]{width:1172px;margin:0 auto}@media (min-width:960px) and (max-width:1279.95px){.site-footer[_yg-server-content-sc82] > *[_yg-server-content-sc82]{width:930px}}@media (max-width:599.95px),(min-width:600px) and (max-width:839.95px),(min-width:840px) and (max-width:959.95px){.site-footer[_yg-server-content-sc82] > *[_yg-server-content-sc82]{width:100%;padding:0 16px}.site-footer[_yg-server-content-sc82]   .header[_yg-server-content-sc82]{margin-bottom:22px}}.site-footer[_yg-server-content-sc82]   .main-container[_yg-server-content-sc82]{display:flex;flex-direction:row;justify-content:space-between;line-height:1.75}@media (max-width:599.95px),(min-width:600px) and (max-width:839.95px),(min-width:840px) and (max-width:959.95px){.site-footer[_yg-server-content-sc82]   .main-container[_yg-server-content-sc82]{flex-direction:column}}.site-footer[_yg-server-content-sc82]   .main-container[_yg-server-content-sc82]   a[_yg-server-content-sc82]{color:#827e8e;text-decoration:none;position:relative;transition:color .25s ease}.site-footer[_yg-server-content-sc82]   .main-container[_yg-server-content-sc82]   a[_yg-server-content-sc82]:after{content:"";position:absolute;bottom:-6px;width:100%;height:1px;left:0;background:#0000;transition:background .25s ease,bottom .25s ease}.site-footer[_yg-server-content-sc82]   .main-container[_yg-server-content-sc82]   a[_yg-server-content-sc82]:hover:after{bottom:-4px;background:#827e8e}.site-footer[_yg-server-content-sc82]   .main-container[_yg-server-content-sc82]   a.active[_yg-server-content-sc82]:after{bottom:-4px;background:#827e8e80}.site-footer[_yg-server-content-sc82]   .main-container[_yg-server-content-sc82]   a.active[_yg-server-content-sc82]:hover:after{background:#827e8e}.site-footer[_yg-server-content-sc82]   .main-container[_yg-server-content-sc82]   .about[_yg-server-content-sc82]{width:335px;font-size:14px;color:#827e8e}@media (max-width:599.95px),(min-width:600px) and (max-width:839.95px),(min-width:840px) and (max-width:959.95px){.site-footer[_yg-server-content-sc82]   .main-container[_yg-server-content-sc82]   .about[_yg-server-content-sc82]{width:100%}}.site-footer[_yg-server-content-sc82]   .main-container[_yg-server-content-sc82]   .about[_yg-server-content-sc82]   .content[_yg-server-content-sc82]{margin:0 0 24px}@media (max-width:599.95px),(min-width:600px) and (max-width:839.95px),(min-width:840px) and (max-width:959.95px){.site-footer[_yg-server-content-sc82]   .main-container[_yg-server-content-sc82]   .about[_yg-server-content-sc82]   .content[_yg-server-content-sc82]{margin-bottom:36px;font-size:18px;line-height:1.5;color:#493f5e}}.site-footer[_yg-server-content-sc82]   .main-container[_yg-server-content-sc82]   .company[_yg-server-content-sc82]{font-weight:700}@media (max-width:599.95px),(min-width:600px) and (max-width:839.95px),(min-width:840px) and (max-width:959.95px){.site-footer[_yg-server-content-sc82]   .main-container[_yg-server-content-sc82]   .company[_yg-server-content-sc82]{margin-bottom:15px;border-top:1px solid #dddae7}}.site-footer[_yg-server-content-sc82]   .main-container[_yg-server-content-sc82]   .company[_yg-server-content-sc82]   .men ...
#
#
# function start(prebootData,win){const _document=(win||window).document||{},currentScript=_document.currentScript||[].slice.call(_document.getElementsByTagName("script"),-1)[0];if(!currentScript)return void console.error("Preboot initialization failed, no currentScript has been detected.");let serverNode=currentScript.parentNode;if(!serverNode)return void console.error("Preboot initialization failed, the script is detached");serverNode.removeChild(currentScript);let eventSelectors=(prebootData.opts||{}).eventSelectors||[];const appData={root:prebootData.opts?getAppRoot(_document,prebootData.opts,serverNode):null,events:[]};prebootData.apps&&prebootData.apps.push(appData),eventSelectors=eventSelectors.map(eventSelector=>(eventSelector.hasOwnProperty("replay")||(eventSelector.replay=!0),eventSelector)),eventSelectors.forEach(eventSelector=>handleEvents(_document,prebootData,appData,eventSelector))}
#
# function createOverlay(_document){let overlay=_document.createElement("div");return overlay.setAttribute("id","prebootOverlay"),overlay.setAttribute("style","display:none;position:absolute;left:0;top:0;width:100%;height:100%;z-index:999999;background:black;opacity:.3"),_document.documentElement.appendChild(overlay),overlay}
#
# function getAppRoot(_document,opts,serverNode){const root={serverNode:serverNode};return root.clientNode=opts.buffer?createBuffer(root):root.serverNode,opts.disableOverlay||(root.overlay=createOverlay(_document)),root}
#
# function handleEvents(_document,prebootData,appData,eventSelector){const serverRoot=appData.root.serverNode;serverRoot&&eventSelector.events.forEach(eventName=>{const handler=createListenHandler(_document,prebootData,eventSelector,appData);serverRoot.addEventListener(eventName,handler,!0),prebootData.listeners&&prebootData.listeners.push({node:serverRoot,eventName:eventName,handler:handler})})}
#
# function createListenHandler(_document,prebootData,eventSelector,appData){const CARET_EVENTS=["keyup","keydown","focusin","mouseup","mousedown"],CARET_NODES=["INPUT","TEXTAREA"],matches=_document.documentElement.matches||_document.documentElement.msMatchesSelector,opts=prebootData.opts;return function(event){const node=event.target;if(!matches.call(node,eventSelector.selector))return;const root=appData.root,eventName=event.type;if(!node||!eventName)return;const keyCodes=eventSelector.keyCodes;if(keyCodes&&keyCodes.length){if(!keyCodes.filter(keyCode=>event.which===keyCode).length)return}eventSelector.preventDefault&&event.preventDefault(),eventSelector.action&&eventSelector.action(node,event);const nodeKey=getNodeKeyForPreboot({root:root,node:node});if(CARET_EVENTS.indexOf(eventName)>=0&&CARET_NODES.indexOf(node.tagName?node.tagName:"")>=0?prebootData.activeNode={root:root,node:node,nodeKey:nodeKey,selection:getSelection(node)}:"change"!==eventName&&"focusout"!==eventName&&(prebootData.activeNode=void 0),opts&&!opts.disableOverlay&&eventSelector.freeze){const overlay=root.overlay;overlay.style.display="block",setTimeout(()=>{overlay.style.display="none"},1e4)}eventSelector.replay&&appData.events.push({node:node,nodeKey:nodeKey,event:event,name:eventName})}}
#
# function getSelection(node){const nodeValue=(node=node||{}).value||"",selection={start:nodeValue.length,end:nodeValue.length,direction:"forward"};try{(node.selectionStart||0===node.selectionStart)&&(selection.start=node.selectionStart,selection.end=node.selectionEnd?node.selectionEnd:0,selection.direction=node.selectionDirection?node.selectionDirection:"none")}catch(ex){}return selection}
#
# function createBuffer(root){const serverNode=root.serverNode;if(!serverNode||!serverNode.parentNode||serverNode===document.documentElement||serverNode===document.body)return serverNode;const rootClientNode=serverNode.cloneNode(!1);return rootClientNode.style.display="none",serverNode.parentNode.insertBefore(rootClientNode,serverNode),serverNode.setAttribute("ng-non-bindable",""),rootClientNode}
#
# function getNodeKeyForPreboot(nodeContext){const ancestors=[],root=nodeContext.root,node=nodeContext.node;let temp=node;for(;temp&&temp!==root.serverNode&&temp!==root.clientNode;)ancestors.push(temp),temp=temp.parentNode;temp&&ancestors.push(temp);let key=node.nodeName||"unknown";for(let i=ancestors.length-1;i>=0;i--)if(temp=ancestors[i],temp.childNodes&&i>0)for(let j=0;j<temp.childNodes.length;j++)if(temp.childNodes[j]===ancestors[i-1]){key+="_s"+(j+1);break}return key}
#
#
#       return (function initAll(opts,win){const theWindow=win||window,data=theWindow.prebootData={opts:opts,apps:[],listeners:[]};return()=>start(data,theWindow)})({"buffer":true,"replay":true,"disableOverlay":false,"eventSelectors":[{"selector":"input,textarea","events":["keypress","keyup","keydown","input","change"]},{"selector":"select,option","events":["change"]},{"selector":"input","events":["keyup"],"preventDefault":true,"keyCodes":[13],"freeze":true},{"selector":"form","events":["submit"],"preventDefault":true,"freeze":true},{"selector":"input,textarea","events":["focusin","focusout","mousedown","mouseup"],"replay":false},{"selector":"button","events":["click"],"preventDefault":true,"freeze":true}],"appRoot":"yg-root"});
#     })();</script><style yg-transition="">.radio-button[_yg-server-content-sc243]   label[_yg-server-content-sc243] > .radio-button-label[_yg-server-content-sc243]{font-size:1rem;font-weight:500;line-height:1.25;height:22px;vertical-align:top;cursor:pointer}@media (min-width:600px) and (max-width:1023.95px),(min-width:1024px) and (max-width:1279.95px){.radio-button[_yg-server-content-sc243]   label[_yg-server-content-sc243] > .radio-button-label[_yg-server-content-sc243]{font-size:1rem;font-weight:500;line-height:1.25;font-size:.875rem;line-height:1.5}}.radio-button[_yg-server-content-sc243]   label[_yg-server-content-sc243] > .radio-button-label[_yg-server-content-sc243]:before{content:"";display:inline-block;vertical-align:top;width:34px;height:22px}.radio-button[_yg-server-content-sc243]   label[_yg-server-content-sc243] > input[type=radio][_yg-server-content-sc243]{display:none;cursor:pointer}.radio-button[_yg-server-content-sc243]   label[_yg-server-content-sc243] > input[type=radio][_yg-server-content-sc243] + .radio-button-label[_yg-server-content-sc243]:before{background:no-repeat 0 url(https://d39be2hlyrutg8.cloudfront.net/6d2f5632/assets/images/svg/titan-ui/radio-unchecked.svg);background-size:22px 22px}.radio-button[_yg-server-content-sc243]   label[_yg-server-content-sc243] > input[type=radio][_yg-server-content-sc243]:checked + .radio-button-label[_yg-server-content-sc243]{font-weight:700;color:#241d36}.radio-button[_yg-server-content-sc243]   label[_yg-server-content-sc243] > input[type=radio][_yg-server-content-sc243]:checked + .radio-button-label[_yg-server-content-sc243]:before{background:no-repeat 0 url(https://d39be2hlyrutg8.cloudfront.net/6d2f5632/assets/images/svg/titan-ui/radio-checked.svg);background-size:22px 22px}@media (max-width:599.95px){.radio-button[_yg-server-content-sc243]   label[_yg-server-content-sc243] > .radio-button-label[_yg-server-content-sc243]{height:22px}.radio-button[_yg-server-content-sc243]   label[_yg-server-content-sc243] > .radio-button-label[_yg-server-content-sc243]:before{width:30px;height:22px}}.radio-list[_yg-server-content-sc243] > .radio-button[_yg-server-content-sc243]{padding-bottom:20px}.radio-list.radio-list-horizontal[_yg-server-content-sc243] > .radio-button[_yg-server-content-sc243]{display:inline-block;padding-right:28px}.radio-list.radio-list-horizontal[_yg-server-content-sc243] > .radio-button[_yg-server-content-sc243]:last-child{padding-right:0}.searchbox[_yg-server-content-sc243] > label[_yg-server-content-sc243]{display:inline-block;height:38px}.searchbox[_yg-server-content-sc243] > label[_yg-server-content-sc243]   input[type=search][_yg-server-content-sc243]{background-size:18px 18px;background:#f2f0f6 url(https://d39be2hlyrutg8.cloudfront.net/6d2f5632/assets/images/svg/titan-ui/search.svg) no-repeat 8px;border:unset;padding:8px 0 9px 31px;border-radius:17.5px;width:285px;height:38px;line-height:38px}@media (min-width:600px) and (max-width:1023.95px),(min-width:1024px) and (max-width:1279.95px){.searchbox[_yg-server-content-sc243] > label[_yg-server-content-sc243]   input[type=search][_yg-server-content-sc243]{width:360px}}.searchbox[_yg-server-content-sc243] > label[_yg-server-content-sc243]   input[type=search][_yg-server-content-sc243]:focus{outline:unset}.searchbox[_yg-server-content-sc243] > label[_yg-server-content-sc243]   input[type=search][_yg-server-content-sc243]::-webkit-search-cancel-button{-webkit-appearance:none}.searchbox[_yg-server-content-sc243] > label[_yg-server-content-sc243] > button.searchbox-cancel[_yg-server-content-sc243]{width:40px;height:40px;border-radius:20px;background:#f7f6fa url(https://d39be2hlyrutg8.cloudfront.net/6d2f5632/assets/images/svg/titan-ui/close.svg) no-repeat 50%;background-size:21px 21px;border:none;background-color:#f2f0f6;position:absolute;right:3%;height:100%}.searchbox.searchbox-expandable[_yg-server-content-sc243] > label[_yg-server-content-sc243] > input[_yg-server-content-sc243]{display:none;background-i ...
#
# @keyframes COLOR_BAR{0%{width:0}to{width:100%}}@media (max-width:599.95px),(min-width:600px) and (max-width:839.95px),(min-width:840px) and (max-width:959.95px){[_yg-server-host-sc233]{display:flex;align-items:center;flex:1;width:100%}}h1[_yg-server-content-sc233]{font-weight:800;font-size:2rem;line-height:1}@media (max-width:599.95px){h1[_yg-server-content-sc233]{font-weight:800;font-size:2rem;line-height:1;font-size:1.5rem;line-height:1.5}}h2[_yg-server-content-sc233]{font-weight:700;font-size:1.25rem;line-height:1.25}h1[_yg-server-content-sc233], h2[_yg-server-content-sc233]{margin:0;text-align:center}a[_yg-server-content-sc233]{font-size:1.125rem;line-height:1.5;font-weight:500;font-weight:700}@media (max-width:599.95px),(min-width:600px) and (max-width:1023.95px),(min-width:1024px) and (max-width:1279.95px){a[_yg-server-content-sc233]{font-size:1.125rem;font-weight:500;font-size:1rem;line-height:1.5;font-weight:700}}div.rankings-header-content[_yg-server-content-sc233]{display:flex;flex-direction:column;align-items:center;justify-content:center;width:100%;padding-bottom:32px;flex:1 0 auto;background-color:var(--rankings-color-white);z-index:131}div.rankings-header-content[_yg-server-content-sc233]   h1[_yg-server-content-sc233]{align-items:center;justify-content:center;height:35px;flex:1;margin-bottom:12px;min-width:calc(100% - (2 * var(--rankings-page-gutter)))}div.rankings-header-content[_yg-server-content-sc233]   h2[_yg-server-content-sc233]{min-height:22px}div.rankings-header-content[_yg-server-content-sc233]   h2[_yg-server-content-sc233] > a[_yg-server-content-sc233]{text-decoration:none;font-size:1rem}div.rankings-header-content[_yg-server-content-sc233]   h2[_yg-server-content-sc233] > a[_yg-server-content-sc233]:hover{text-decoration:underline}@media (max-width:599.95px),(min-width:600px) and (max-width:839.95px){div.rankings-header-content[_yg-server-content-sc233]   h1[_yg-server-content-sc233], div.rankings-header-content[_yg-server-content-sc233]   h2[_yg-server-content-sc233]{display:-webkit-box;overflow:hidden;margin-bottom:-.1em;padding-bottom:.1em;text-overflow:ellipsis;-webkit-line-clamp:3;-webkit-box-orient:vertical}}@media (min-width:840px) and (max-width:959.95px){div.rankings-header-content[_yg-server-content-sc233]   h1[_yg-server-content-sc233], div.rankings-header-content[_yg-server-content-sc233]   h2[_yg-server-content-sc233]{display:-webkit-box;overflow:hidden;margin-bottom:-.1em;padding-bottom:.1em;text-overflow:ellipsis;-webkit-line-clamp:2;-webkit-box-orient:vertical}}div.rankings-header-content.rankings-header-content-stuck[_yg-server-content-sc233]{font-weight:800;font-size:2rem;line-height:1;font-size:1.5rem;line-height:1.5;display:flex;align-items:center;background-color:var(--rankings-color-white)}@media (min-width:960px) and (max-width:1279.95px),(min-width:1280px){div.rankings-header-content.rankings-header-content-stuck[_yg-server-content-sc233]{padding:12px 0}}@media (min-width:1024px) and (max-width:1279.95px),(min-width:1280px){div.rankings-header-content[_yg-server-content-sc233]   h2[_yg-server-content-sc233]{font-size:1rem;font-weight:500;line-height:1.25}div.rankings-header-content.rankings-header-content-shift[_yg-server-content-sc233]{padding-top:32px}}@media (min-width:1024px) and (max-width:1279.95px){div.rankings-header-content[_yg-server-content-sc233]   h1[_yg-server-content-sc233]{height:40px}div.rankings-header-content[_yg-server-content-sc233]   .rankings-header-content-stuck[_yg-server-content-sc233]   h1[_yg-server-content-sc233]{height:33px;font-size:1.25rem}}@media (max-width:599.95px),(min-width:600px) and (max-width:1023.95px){div.rankings-header-content.rankings-header-content-stuck[_yg-server-content-sc233]{padding-bottom:0}}@media (min-width:600px) and (max-width:1023.95px){div.rankings-header-content[_yg-server-content-sc233]{padding-top:0}div.rankings-header-content[_yg-server-content-sc233]   h1[_yg-server-content-sc233]{margin-bottom:12px}div.rankings-h ...
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MRSS3JG" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <yg-root _yg-server-host-sc83="" class="ng-tns-c83-0" ng-version="11.2.14"><script class="preboot-inline-script">prebootInitFn();</script><div _yg-server-content-sc83="" class="ng-tns-c83-0 ng-trigger ng-trigger-routeAnimation" style=""><router-outlet _yg-server-content-sc83="" class="ng-tns-c83-0" name="popup"></router-outlet><!-- --></div><div _yg-server-content-sc83="" class="app-container ng-tns-c83-0 ng-trigger ng-trigger-routeAnimation" style=""><yg-covid-announcement _yg-server-content-sc83="" _yg-server-host-sc63="" class="ng-tns-c83-0"><!-- --></yg-covid-announcement><yg-menu _yg-server-content-sc83="" _yg-server-host-sc80="" class="ng-tns-c83-0"><yg-primary-menu _yg-server-content-sc80="" _yg-server-host-sc79=""><yg-main-menu _yg-server-content-sc79="" _yg-server-host-sc76=""><div _yg-server-content-sc76="" class="main-menu" data-cy="main-menu"><ul _yg-server-content-sc76="" class="main-nav" data-cy="main-nav"><li _yg-server-content-sc76="" class="item country-menu-item"><button _yg-server-content-sc76="" aria-label="Select language" class="item-button yg-button red size-inline rounded" id="toggleCountryMenu" type="button" ygbutton="" ygsize="size-inline"> UK <svg _yg-server-content-sc76="" class="item-icon chevron-icon" height="14" viewbox="0 0 14 14" width="14" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><path _yg-server-content-sc76="" d="M8.237 9.333L7 10.571 5.763 9.333 1.432 5.002 2.669 3.765 7 8.096 11.331 3.765 12.568 5.002z" fill="#9A93A8"></path></svg><svg _yg-server-content-sc76="" class="item-icon close-icon" height="14" viewbox="0 0 14 14" width="14" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><path _yg-server-content-sc76="" d="M8.237 7L12.568 11.331 11.331 12.568 7 8.237 2.669 12.568 1.432 11.331 5.763 7 1.432 2.669 2.669 1.432 7 5.763 11.331 1.432 12.568 2.669z" id="yodjelf6xa"></path><mask _yg-server-content-sc76="" fill="#fff" id="fq378mx0eb"><use _yg-server-content-sc76="" xlink:href="#yodjelf6xa"></use></mask><g _yg-server-content-sc76="" fill="#241D36" mask="url(#fq378mx0eb)"><path _yg-server-content-sc76="" d="M0 0H14V14H0z" fill="#241D36"></path></g></svg></button></li><li _yg-server-content-sc76="" class="item ng-star-inserted" data-cy="about-url" style=""><a _yg-server-content-sc76="" aria-label="Link to about page" class="item-link focus-state" href="https://yougov.co.uk/about/" rel="noopener" ygfocusstate="">About</a></li><!-- --><li _yg-server-content-sc76="" class="item" data-cy="business-href"><a _yg-server-content-sc76="" aria-label="Link to business page" class="item-link special-link external-link focus-state" href="https://business.yougov.com" rel="noopener" ygfocusstate=""> For business <svg _yg-server-content-sc76="" class="item-icon" height="14" width="14" xmlns="http://www.w3.org/2000/svg"><path _yg-server-content-sc76="" d="M5.324.583v1.604H2.12v9.694l9.694.003V8.748h1.602v4.672L.583 13.417V.583h4.74zm7.595 0l.492.002v5.429h-1.6V3.213L6.848 8.174 5.717 7.042l4.858-4.858H8.117v-1.6h4.802z" fill="#00A3A0"></path></svg></a></li></ul><a _yg-server-content-sc76="" aria-label="Link to homepage" class="logo focus-state" data-cy="logo" href="/" ygfocusstate=""><!-- --><img _yg-server-content-sc76="" alt="logo" class="logo-image uk-logo-image ng-star-inserted" height="32" src="https://d39be2hlyrutg8.cloudfront.net/6d2f5632/assets/images/svg/logo-uk.svg" style="" width="138"/><!-- --></a><!-- --><div _yg-server-content-sc76="" class="mobile-menu-container" data-cy="mobile-menu"><button _yg-server-content-sc76="" aria-label="Open content menu" class="button hamburger-button yg-button red size-inline rounded" data-cy="hamburger-button" type="button" ygbutton="" ygsize="size-inline"><svg _yg-server-content-sc76="" class="icon" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><path _yg-server-content-sc76="" d="M17.25 13.125v2.25H.75v-2.25h16.5zm0-5.25v2. ...
# <script defer="" src="https://d39be2hlyrutg8.cloudfront.net/6d2f5632/runtime.js"></script><script defer="" src="https://d39be2hlyrutg8.cloudfront.net/6d2f5632/polyfills.js"></script><script defer="" src="https://d39be2hlyrutg8.cloudfront.net/6d2f5632/main.js"></script>
</span><i _yg-server-content-sc236="" class="icon arrow-up"></i></span>,
#  <span _yg-server-content-sc236="">30%</span>,
#  <span _yg-server-content-sc82="">Company</span>,
#  <span _yg-server-content-sc82="">Global Sites</span>]

# %%
supermarket1 = soup_span[15].text
supermarket2 = soup_span[22].text
supermarket3 = soup_span[29].text
supermarket4 = soup_span[36].text
supermarket5 = soup_span[43].text
supermarket6 = soup_span[50].text
supermarket7 = soup_span[57].text
supermarket8 = soup_span[64].text
supermarket9 = soup_span[71].text
supermarket10 = soup_span[78].text
supermarket11 = soup_span[85].text
supermarket12 = soup_span[92].text
supermarket13 = soup_span[99].text
supermarket14 = soup_span[106].text
supermarket15 = soup_span[113].text
supermarket16 = soup_span[120].text
supermarket17 = soup_span[127].text
supermarket18 = soup_span[134].text
supermarket19 = soup_span[141].text
supermarket20 = soup_span[148].text

# %%
soup_1 = soup.find_all("span", class_="rankings-item-active")
soup_1
# Out:
# [<span _yg-server-content-sc236="" class="rankings-item-active"><span _yg-server-content-sc236="">76%</span><i _yg-server-content-sc236="" class="icon arrow-up"></i></span>,
#  <span _yg-server-content-sc236="" class="rankings-item-active"><span _yg-server-content-sc236="">75%</span><i _yg-server-content-sc236="" class="icon arrow-up"></i></span>,
#  <span _yg-server-content-sc236="" class="rankings-item-active"><span _yg-server-content-sc236="">73%</span><i _yg-server-content-sc236="" class="icon arrow-up"></i></span>,
#  <span _yg-server-content-sc236="" class="rankings-item-active"><span _yg-server-content-sc236="">71%</span><i _yg-server-content-sc236="" class="icon arrow-up"></i></span>,
#  <span _yg-server-content-sc236="" class="rankings-item-active"><span _yg-server-content-sc236="">69%</span><i _yg-server-content-sc236="" class="icon arrow-down"></i></span>,
#  <span _yg-server-content-sc236="" class="rankings-item-active"><span _yg-server-content-sc236="">68%</span><i _yg-server-content-sc236="" class="icon arrow-down"></i></span>,
#  <span _yg-server-content-sc236="" class="rankings-item-active"><span _yg-server-content-sc236="">66%</span><i _yg-server-content-sc236="" class="icon arrow-down"></i></span>,
#  <span _yg-server-content-sc236="" class="rankings-item-active"><span _yg-server-content-sc236="">66%</span><i _yg-server-content-sc236="" class="icon arrow-up"></i></span>,
#  <span _yg-server-content-sc236="" class="rankings-item-active"><span _yg-server-content-sc236="">64%</span><i _yg-server-content-sc236="" class="icon arrow-down"></i></span>,
#  <span _yg-server-content-sc236="" class="rankings-item-active"><span _yg-server-content-sc236="">64%</span><i _yg-server-content-sc236="" class="icon arrow-down"></i></span>,
#  <span _yg-server-content-sc236="" class="rankings-item-active"><span _yg-server-content-sc236="">61%</span><i _yg-server-content-sc236="" class="icon arrow-up"></i></span>,
#  <span _yg-server-content-sc236="" class="rankings-item-active"><span _yg-server-content-sc236="">59%</span><i _yg-server-content-sc236="" class="icon arrow-up"></i></span>,
#  <span _yg-server-content-sc236="" class="rankings-item-active"><span _yg-server-content-sc236="">53%</span><i _yg-server-content-sc236="" class="icon arrow-up"></i></span>,
#  <span _yg-server-content-sc236="" class="rankings-item-active"><span _yg-server-content-sc236="">46%</span><i _yg-server-content-sc236="" class="icon arrow-up"></i></span>,
#  <span _yg-server-content-sc236="" class="rankings-item-active"><span _yg-server-content-sc236="">45%</span><i _yg-server-content-sc236="" class="icon arrow-down"></i></span>,
#  <span _yg-server-content-sc236="" class="rankings-item-active"><span _yg-server-content-sc236="">38%</span><i _yg-server-content-sc236="" class="icon arrow-down"></i></span>,
#  <span _yg-server-content-sc236="" class="rankings-item-active"><span _yg-server-content-sc236="">37%</span><i _yg-server-content-sc236="" class="icon arrow-down"></i></span>,
#  <span _yg-server-content-sc236="" class="rankings-item-active"><span _yg-server-content-sc236="">32%</span><i _yg-server-content-sc236="" class="icon arrow-up"></i></span>,
#  <span _yg-server-content-sc236="" class="rankings-item-active"><span _yg-server-content-sc236="">31%</span><i _yg-server-content-sc236="" class="icon arrow-up"></i></span>,
#  <span _yg-server-content-sc236="" class="rankings-item-active"><span _yg-server-content-sc236="">30%</span><i _yg-server-content-sc236="" class="icon arrow-up"></i></span>]

# %%
popularity1 = soup_1[0].text
popularity2 = soup_1[1].text
popularity3 = soup_1[2].text
popularity4 = soup_1[3].text
popularity5 = soup_1[4].text
popularity6 = soup_1[5].text
popularity7 = soup_1[6].text
popularity8 = soup_1[7].text
popularity9 = soup_1[8].text
popularity10 = soup_1[9].text
popularity11 = soup_1[10].text
popularity12 = soup_1[11].text
popularity13 = soup_1[12].text
popularity14 = soup_1[13].text
popularity15 = soup_1[14].text
popularity16 = soup_1[15].text
popularity17 = soup_1[16].text
popularity18 = soup_1[18].text
popularity19 = soup_1[19].text

# %%
numpy_array =np.array([[supermarket1, popularity1], [supermarket2, popularity2], [supermarket3, popularity3], [supermarket4, popularity4], [supermarket5, popularity5], [supermarket6, popularity6], [supermarket7, popularity7], [supermarket8, popularity8], [supermarket9, popularity9], [supermarket10, popularity10], [supermarket11, popularity11], [supermarket12, popularity12]])

# %%
df = pd.DataFrame(numpy_array)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-893ec63afc55> in <module>()
# ----> 1 df = pd.DataFrame(numpy_array)
#
# NameError: name 'pd' is not defined

# %%
str. rstrip("%","")
# Out:
# '%'

# %%
df.head(10)
# Out:
#                        0    1
# 0                   Aldi  76%
# 1             M & S Food  75%
# 2                   Lidl  73%
# 3  The Co-operative Food  71%
# 4              Morrisons  69%
# 5        Sainsbury&aposs  68%
# 6                  Tesco  66%
# 7                Iceland  66%
# 8                   ASDA  64%
# 9          Tesco Express  64%

# %%
df4['1'] = list(map(lambda x:x[:-1], df4['1'].values))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-f6ffcb8a6341> in <module>()
# ----> 1 df4['1'] = list(map(lambda x:x[:-1], df4['1'].values))
#
# NameError: name 'df4' is not defined

# %%
df.head(10)
# Out:
#                        0    1
# 0                   Aldi  76%
# 1             M & S Food  75%
# 2                   Lidl  73%
# 3  The Co-operative Food  71%
# 4              Morrisons  69%
# 5        Sainsbury&aposs  68%
# 6                  Tesco  66%
# 7                Iceland  66%
# 8                   ASDA  64%
# 9          Tesco Express  64%

# %%
df.to_csv('my_data_scraping.csv')
